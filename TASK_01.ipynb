# %%
import pandas as pd
import os

# %%
# Write the code to read the csv file and the excel file and convert them into the Data frame. 

s1=pd.read_csv('C:\\Users\\vijju\\Desktop\\intership\\car_model.csv',encoding='cp1252')
s1.head()
# Out:
#      Company Name     Model Name    Fuel Type  Body Style  Car Length
# 0      Hyundai i10  Accord Hybrid      Petrol    Hatchback        13.8
# 1     Maruti Swift            Air      Diesel        Sedan        14.4
# 2   Maruti Wagon R         Altima         CNG          SUV        14.8
# 3    Hyundai Creta          Ariya  Bio-Diesel        Coupe        15.7
# 4  Mahindra XUV500         Avalon         LPG  Convertible       16.3

# %%
s2=pd.read_excel(r"C:\\Users\\vijju\\Desktop\\intership\\car prizing.xlsx")
s2.head()
# Out:
#      Company Name     Model Name   On road pricing   Loan amount   \
# 0      Hyundai i10  Accord Hybrid            300000        330000
# 1     Maruti Swift            Air            400000        340000
# 2   Maruti Wagon R         Altima             50000        430000
# 3    Hyundai Creta          Ariya            600000        530000
# 4  Mahindra XUV500         Avalon             59900        530000
#
#    Monthly EMI   Interest Rate   Monthly Principal   Monthly Interest
# 0         15000           0.023               40000              0.045
# 1         10000           0.034              300000              0.045
# 2         11000           0.045               59000              0.040
# 3         10000           0.056               48300              0.060
# 4         12000           0.089               93900              0.070

# %%
# Merge the two Data frame on the basis of primary key 

marge1=[s1,s2]
a=pd.concat(marge1)
a.head()
# Out:
#      Company Name     Model Name    Fuel Type  Body Style  Car Length   \
# 0      Hyundai i10  Accord Hybrid      Petrol    Hatchback        13.8
# 1     Maruti Swift            Air      Diesel        Sedan        14.4
# 2   Maruti Wagon R         Altima         CNG          SUV        14.8
# 3    Hyundai Creta          Ariya  Bio-Diesel        Coupe        15.7
# 4  Mahindra XUV500         Avalon         LPG  Convertible       16.3
#
#    On road pricing   Loan amount   Monthly EMI   Interest Rate   \
# 0               NaN           NaN           NaN             NaN
# 1               NaN           NaN           NaN             NaN
# 2               NaN           NaN           NaN             NaN
# 3               NaN           NaN           NaN             NaN
# 4               NaN           NaN           NaN             NaN
#
#    Monthly Principal   Monthly Interest
# 0                 NaN                NaN
# 1                 NaN                NaN
# 2                 NaN                NaN
# 3                 NaN                NaN
# 4                 NaN                NaN
